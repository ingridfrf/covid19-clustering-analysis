# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

dt = pd.read_excel('/content/base_de_dados_final.xlsm', index_col=0) #para o nome do país ficar como índice

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39623 entries, Aruba to Zimbabwe
# Data columns (total 60 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   date                                                                        39623 non-null  datetime64[ns]
#  1   código_do_país                                                              39623 non-null  object
#  2   stringency_index                                                            39623 non-null  float64
#  3   fechamento_de_escolas                                                       39623 non-null  int64
#  4   flag_fechamento_de_escolas                                                  39623 non-null  int64
#  5   fechamentos_locais_de_trabalho                                              39623 non-null  int64
# ...

# %%
boxplot = dt.boxplot(column=['fechamento_de_escolas','fechamentos_locais_de_trabalho']) 
plt.yticks(range(4))
plt.title('Fechamento de escolas X locais de trabalho')
# Out:
# Text(0.5, 1.0, 'Fechamento de escolas X locais de trabalho')

# %%
boxplot = dt.boxplot(column=['obrigatoriedade_de_ficar_em_casa','movimentações_internas_entre_cidades_e_regiões'])
plt.yticks(range(4))
# Out:
# ([<matplotlib.axis.YTick at 0x7fc8b7b18f90>,
# ...
#  <a list of 4 Text major ticklabel objects>)

# %%
dt['stringency_index'].hist()

# %%
dt['stringency_index'].hist(bins=20)

# %%
x = np.arange(4)
plt.bar(range(4), height=range(4))
plt.xticks(x, range(4))
plt.ylim(0,20000)
dt['fechamento_de_escolas'].hist(bins=10)
plt.title('Fechamento de escolas')
plt.xlabel ('Flags') 
plt.ylabel ('Somatório de ocorrências');

# %%
x = np.arange(4)
plt.bar(range(4), height=range(4))
plt.xticks(x, range(4))
plt.ylim(0,20000)
dt['fechamentos_locais_de_trabalho'].hist(bins=10)
plt.title('Fechamento dos locais de trabalho')
plt.xlabel ('Flags') 
plt.ylabel ('Somatório de ocorrências')
# Out:
# Text(0, 0.5, 'Somatório de ocorrências')

# %%
x = np.arange(3)
plt.bar(range(3), height=range(3))
plt.xticks(x, range(3))
plt.ylim(0,25000)
dt['cancelamento_eventos_locais_publicos'].hist(bins=10)
plt.title('Cancelamento de eventos em locais públicos')
plt.xlabel ('Flags') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(3))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8b84a7c90>,
# ...
#  <a list of 3 Text major ticklabel objects>)

# %%
x = np.arange(5)
plt.bar(range(5), height=range(5))
plt.xticks(x, range(5))
plt.ylim(0,25000)
dt['restrição_de_aglomerção_em_locais_privados'].hist(bins=30)
plt.title('Restrição de aglomerção em locais privados')
plt.xlabel ('Flags') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(5))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8b838b1d0>,
# ...
#  <a list of 5 Text major ticklabel objects>)

# %%
x = np.arange(5)
plt.bar(range(5), height=range(5))
plt.xticks(x, range(5))
plt.ylim(0,17500)
dt['fechamento_do_transporte_público'].hist(bins=30)
plt.title('Fechamento do transporte público')
plt.xlabel ('Flags ') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(4))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8d064d950>,
# ...
#  <a list of 4 Text major ticklabel objects>)

# %%
x = np.arange(4)
plt.bar(range(4), height=range(4))
plt.xticks(x, range(4))
plt.ylim(0,19000)
dt['obrigatoriedade_de_ficar_em_casa'].hist(bins=30)
plt.title('Obrigatoriedade de ficar em casa')
plt.xlabel ('Flags') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(4))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8b7fc6090>,
# ...
#  <a list of 4 Text major ticklabel objects>)

# %%
x = np.arange(3)
plt.bar(range(3), height=range(3))
plt.xticks(x, range(3))
plt.ylim(0,19000)
dt['movimentações_internas_entre_cidades_e_regiões'].hist(bins=30)
plt.title('Movimentações internas entre cidades e regiões')
plt.xlabel ('Flags ') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(3))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8b8102b10>,
# ...
#  <a list of 3 Text major ticklabel objects>)

# %%
dt['controle_de viagens_internacionais'].hist(bins=30)
plt.title('Controle de viagens internacionais')
plt.xlabel ('Flags') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(4))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8cc1a9ad0>,
# ...
#  <a list of 4 Text major ticklabel objects>)

# %%
dt['ajuda_de custos_para_ quem_perdeu_emprego_ou_não_pode_trabalhar'].hist(bins=30)

# %%
dt['alívio_de_dividas_e_contratos'].hist(bins=30)

# %%
dt['campanhas_públicas_de_conscientização'].hist(bins=30)

# %%
x = np.arange(4)
plt.bar(range(4), height=range(4))
plt.xticks(x, range(4))
plt.ylim(0,19000)
dt['política_de_testagem'].hist(bins=30)
plt.title('Política de Testagem')
plt.xlabel ('Flags') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(4))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8b8089750>,
# ...
#  <a list of 4 Text major ticklabel objects>)

# %%
x = np.arange(3)
plt.bar(range(3), height=range(3))
plt.xticks(x, range(3))
plt.ylim(0,19000)
dt['rastreamento_de_contagio'].hist(bins=30)
plt.title('Rastreamento de contágio')
plt.xlabel ('Flags ') 
plt.ylabel ('Somatório de ocorrências')
plt.xticks(range(3))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc8b7c5c710>,
# ...
#  <a list of 3 Text major ticklabel objects>)
