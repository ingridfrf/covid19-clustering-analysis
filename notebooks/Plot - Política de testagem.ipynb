# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import matplotlib.dates as mdates
cluster0 = pd.read_excel('/content/CLUSTER 0 HDBSCAN.xlsx')
cluster1 = pd.read_excel('/content/CLUSTER 1 HDBSCAN.xlsx')
cluster2 = pd.read_excel('/content/CLUSTER 2 HDBSCAN.xlsx')
cluster3 = pd.read_excel('/content/CLUSTER 3 HDBSCAN.xlsm')

# %%
def plot_cluster(cluster, coluna):
  plt.figure(figsize=(10,8))
  for pais in cluster['país'].unique():
    pais_df = cluster[cluster['país'] == pais]
    plt.plot(pais_df['date'], pais_df[coluna])
  plt.yticks(range(4))
  plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');

# %%
plot_cluster(cluster0[cluster0['país'] == 'United States'], 'política_de_testagem')
plt.title('Política de Testagem - EUA')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster1[cluster1['país'] == 'Italy'], 'política_de_testagem')
plt.title('Política de Testagem - Itália')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster1[cluster1['país'] == 'Spain'], 'política_de_testagem')
plt.title('Política de Testagem - Espanha')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster2[cluster2['país'] == 'Chile'], 'política_de_testagem')
plt.title('Política de Testagem - Chile')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster3[cluster3['país'] == 'India'], 'política_de_testagem')
plt.title('Política de Testagem - Índia')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster3[cluster3['país'] == 'Brazil'], 'política_de_testagem')
plt.title('Política de Testagem - Brasil')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster0[cluster0['país'] == 'San Marino'], 'política_de_testagem')
plt.title('Política de Testagem - San Marino')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster0[cluster0['país'] == 'Andorra'], 'política_de_testagem')
plt.title('Política de Testagem - Andorra')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster1[cluster1['país'] == 'Aruba'], 'política_de_testagem')
plt.title('Política de Testagem - Aruba')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster1[cluster1['país'] == 'Kuwait'], 'política_de_testagem')
plt.title('Política de Testagem - Kuwait')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster3[cluster3['país'] == 'Peru'], 'política_de_testagem')
plt.title('Política de Testagem - Peru')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Apenas para aqueles que apresentam sintomas e atingem um critério específico', (mdates.date2num(dt.datetime(2020, 1, 11)), 1.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')

# %%
plot_cluster(cluster2[cluster2['país'] == 'Panama'], 'política_de_testagem')
plt.title('Política de Testagem - Panamá')
plt.annotate('Sem política de testagem', (mdates.date2num(dt.datetime(2020, 1, 11)), 0.05))
plt.annotate('Testagem em todos que apresentam sintomas', (mdates.date2num(dt.datetime(2020, 1, 11)), 2.05))
plt.annotate('Testagem aberta para a população em geral', (mdates.date2num(dt.datetime(2020, 1, 11)), 3.05))
# Out:
# No handles with labels found to put in legend.
# Text(737435.0, 3.05, 'Testagem aberta para a população em geral')
